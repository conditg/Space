# %%
import numpy as np
import pandas as pd
from collections import OrderedDict

# %%
#read in the observations data. multiple observations for each of the ~8K objects
df = pd.read_csv('training_set.csv')

# %%
#easy dict for reassigning passband index to their letters
pbmap = OrderedDict([(0,'u'), (1,'g'), (2,'r'), (3,'i'), (4, 'z'), (5, 'Y')])
pbnames= list(pbmap.values())

# %%
#create the flux features we want and fix the columns. output should be rows of length~8K (one per object)
#and one column for each passband/feature combination: 30
feats = df.groupby(['object_id', 'passband'])['flux'].agg(['mean', 'median', 'std', 'max', 'min'])
feats = feats.unstack(level='passband')
newcols=[]
for x in feats.columns.levels[1]:
    newcols.append([y + "_" + pbmap[x] for y in feats.columns.levels[0]])
feats.columns =[item for sublist in newcols for item in sublist]
feats.head()
# Out:
#              mean_u    median_u       std_u       max_u      min_u     mean_g  \
# object_id
# 615       -3.254554 -385.699911 -134.146566 -121.103501 -55.954592 -47.449847
# 713       -2.720398   -1.019804   -0.794238   -0.986966  -0.900262  -1.794175
# 730       -0.048080    0.141057    2.400870    3.236164   4.308728   4.539396
# 745        1.797523    5.717394    9.711532   14.412924  13.134436  10.746138
# 1124       0.660948    4.634637   10.243968   11.086555   9.906102   6.896742
#
#             median_g       std_g       max_g       min_g     ...      \
# object_id                                                    ...
# 615       -10.015225 -488.057969 -265.686004 -162.170944     ...
# 713        -3.096804   -0.561735   -0.117977   -0.073896     ...
# 730         0.024093    0.171336    0.491790    0.660403     ...
# 745         1.056714    0.888115    0.424360    1.361369     ...
# 1124        0.581027    1.154596    0.889142    1.014105     ...
#
#                mean_z    median_z       std_z       max_z       min_z  \
# object_id
# 615        611.984558  445.737061  381.953735  378.188141 -116.913223
# 713         10.529041   11.330316    9.827934   14.770886  -14.735178
# 730         20.994711   33.572102   41.159981   47.310059   -3.459960
# 745        220.795212  203.250702  183.633118  141.513290   -3.874349
# 1124       106.671692  139.818405  143.600189  109.157585   -6.804703
#
#                 mean_Y    median_Y       std_Y       max_Y       min_Y
# object_id
# 615       -1100.440063 -681.858887 -530.644592 -422.184509 -422.815094
# 713         -11.715749  -10.067919  -12.394593  -12.286801  -14.211164
# 730          -3.393080   -2.848838   -5.435799   -5.836310  -19.159811
# 745          -3.618410   -2.159753   -4.944036  -15.494463  -10.249387
# 1124         -2.622109   -2.084535   -2.800270  -16.543753  -10.860540
#
# [5 rows x 30 columns]

# %%
#create the flux_error features we want and merge with the flux features above.

errs = df.groupby(['object_id', 'passband'])['flux_err'].agg(['std'])
errs = errs.unstack(level='passband')
newcols=[]
for x in errs.columns.levels[1]:
    newcols.append(["errstd" + "_" + pbmap[x] for y in errs.columns.levels[0]])
errs.columns =[item for sublist in newcols for item in sublist]

# %%
#output should be rows of length~8K (one per object)
#and one column for each passband/feature combination, now 36
feats = feats.merge(errs, left_index=True, right_index=True)

# %%
#read in metadata and merge that as well. output is now 8K rows and 48 columns: 
#30 flux feats, 6 flux_error feats, and 12 metadata columns
metadata = pd.read_csv('training_set_metadata.csv')
metadata.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  ddf  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706    1
# 1        713   53.085938 -27.784405  223.525509 -54.460748    1
# 2        730   33.574219  -6.579593  170.455585 -61.548219    1
# 3        745    0.189873 -45.586655  328.254458 -68.969298    1
# 4       1124  352.711273 -63.823658  316.922299 -51.059403    1
#
#    hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# 0         0.0000          0.0000              0.0000      NaN  0.017      92
# 1         1.8181          1.6267              0.2552  45.4063  0.007      88
# 2         0.2320          0.2262              0.0157  40.2561  0.021      42
# 3         0.3037          0.2813              1.1523  40.7951  0.007      90
# 4         0.1934          0.2415              0.0176  40.4166  0.024      90

# %%
feats = feats.reset_index()
feats = feats.merge(metadata, left_on='object_id', right_on='object_id')

# %%
#Write to csv
feats.to_csv('trainingfeats.csv', index=False)
